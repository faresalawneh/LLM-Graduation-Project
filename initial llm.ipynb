# %%
# !pip install vllm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.2/433.2 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.6/192.6 kB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 72.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.4/469.4 kB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 15.7 MB/s eta 0:00:00
# ...

# %%
# !vllm serve facebook/opt-125m --port 8000 &
# Out:
# 2026-03-26 16:08:55.485988: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774541335.511452   17652 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774541335.518905   17652 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774541335.538494   17652 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import subprocess, os

env = os.environ.copy()
env["PATH"] = "/usr/local/bin:" + env["PATH"]

subprocess.Popen(
    ["vllm", "serve", "facebook/opt-125m", "--port", "8000"],
    env=env
)
# Out:
# <Popen: returncode: None args: ['vllm', 'serve', 'facebook/opt-125m', '--por...>

# %%
import subprocess
result = subprocess.run(["pgrep", "-f", "vllm"], capture_output=True, text=True)
print(result.stdout)
# Out:
# 19877

# %%
import time, requests
for i in range(12):
    try:
        r = requests.get("http://localhost:8000/v1/models")
        print(r.json())
        break
    except:
        print(f"محاولة {i+1}... استنى")
        time.sleep(10)
# Out:
# محاولة 1... استنى
# محاولة 2... استنى
# محاولة 3... استنى
# محاولة 4... استنى
# محاولة 5... استنى
# محاولة 6... استنى
# محاولة 7... استنى
# {'object': 'list', 'data': [{'id': 'facebook/opt-125m', 'object': 'model', 'created': 1774541835, 'owned_by': 'vllm', 'root': 'facebook/opt-125m', 'parent': None, 'max_model_len': 2048, 'permission': [{'id': 'modelperm-ac2dd0c483a5989d', 'object': 'model_permission', 'created': 1774541835, 'allow_create_engine': False, 'allow_sampling': True, 'allow_logprobs': True, 'allow_search_indices': False, 'allow_view': True, 'allow_fine_tuning': False, 'organization': '*', 'group': None, 'is_blocking': False}]}]}

# %%
# !pip install aiperf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 126.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.0/204.0 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 120.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 126.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 122.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-42866291-6e94-420d-9f50-c2b4ebb98f75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42866291-6e94-420d-9f50-c2b4ebb98f75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

# المسارات الخاصة بك
zip_path = '/content/BurstGPT_without_fails_3.zip'
extract_path = '/content/BurstGPT_data'

# تنفيذ عملية فك الضغط
try:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

    print("✅ تم فك الضغط بنجاح!")
    print(f"📁 الملفات موجودة الآن في: {extract_path}")

    # عرض قائمة بالملفات المفكوكة (اختياري)
    files = os.listdir(extract_path)
    print(f"📄 عدد الملفات المستخرجة: {len(files)}")

except FileNotFoundError:
    print("❌ خطأ: لم يتم العثور على ملف الـ zip في المسار المحدد.")
except Exception as e:
    print(f"⚠️ حدث خطأ غير متوقع: {e}")
# Out:
# ✅ تم فك الضغط بنجاح!
# 📁 الملفات موجودة الآن في: /content/BurstGPT_data
# 📄 عدد الملفات المستخرجة: 1

# %%
import pandas as pd
df = pd.read_csv("/content/BurstGPT_data/BurstGPT_without_fails_3.csv")
print(df.shape)
print(df.head())
# Out:
# (4956058, 8)
#     Timestamp                            Session ID  Elapsed time    Model  \
# 0  19440110.0  1722ac82-0a46-4bf0-aa08-89794e7a2b3f            43    GPT-4
# 1  19440161.0  d5983bf9-4b48-497b-892b-a58995247443             2  ChatGPT
# 2  19440192.0  a5c69b35-4fbc-45e9-955e-18715e376d74             8    GPT-4
# 3  19440254.0  8b74c7d8-1643-4bba-8c69-91cb4548c506             3  ChatGPT
# 4  19440301.0  1722ac82-0a46-4bf0-aa08-89794e7a2b3f            26    GPT-4
#
#    Request tokens  Response tokens  Total tokens          Log Type
# 0             906              446          1352  Conversation log
# 1              36               29            65  Conversation log
# 2            1779              123          1902  Conversation log
# 3             935              178          1113  Conversation log
# 4            1631              282          1913  Conversation log

# %%
import subprocess
import json

result = subprocess.run([
    "aiperf", "profile", "facebook/opt-125m",
    "--url", "http://localhost:8000",
    "--endpoint-type", "completions",
    "--streaming",
    "--request-count", "100",
    "--concurrency", "5",
    "--gpu-telemetry", "pynvml",
    "--ui-type", "simple",
    "--output-artifact-dir", "artifacts"
], capture_output=True, text=True)

print(result.stdout)
print(result.stderr)
# Out:
# 16:19:21.858 INFO     Starting AIPerf System (cli_runner.py:75)
# 16:19:22.273 INFO     ✓ Tokenizer facebook/opt-125m detected (tokenizer_display.py:203)
# 16:19:22.273 INFO     1 tokenizer validated • 0.4s (tokenizer_display.py:212)
# 16:19:22.552 INFO     Server Metrics: Discovered 1 endpoints: ['http://localhost:8000/metrics'] (manager.py:70)
# 16:19:22.591 INFO     Registered Gpu Telemetry Manager (id: 'gpu_telemetry_manager') (system_controller.py:340)
# 16:19:22.596 INFO     Registered Worker Manager (id: 'worker_manager') (system_controller.py:340)
# 16:19:22.596 INFO     GPU telemetry export enabled: artifacts/gpu_telemetry_export.jsonl (jsonl_writer.py:53)
# 16:19:22.601 INFO     Record metrics export enabled: artifacts/profile_export.jsonl (record_export_results_processor.py:53)
# 16:19:22.671 INFO     Registered Server Metrics Manager (id: 'server_metrics_manager') (system_controller.py:340)
# ...

# %%
# تأكد أن الرابط لا ينتهي بـ /
PUSHGATEWAY_URL = " https://unrevised-tate-facetiously.ngrok-free.dev"

# تأكد من المسار الصحيح
r = requests.post(
    f"{PUSHGATEWAY_URL}/metrics/job/aiperf",
    data=metrics,
    headers=headers
)
print(r.status_code)
# Out:
# 200

# %%
import requests

PUSHGATEWAY_URL = "https://unrevised-tate-facetiously.ngrok-free.dev"

metrics = """
# HELP ttft_ms Time to first token in milliseconds
# TYPE ttft_ms gauge
ttft_ms 89.25

# HELP itl_ms Inter token latency in milliseconds
# TYPE itl_ms gauge
itl_ms 5.19

# HELP request_latency_ms Request latency in milliseconds
# TYPE request_latency_ms gauge
request_latency_ms 166.69

# HELP throughput_tokens_per_sec Output token throughput
# TYPE throughput_tokens_per_sec gauge
throughput_tokens_per_sec 446.90
"""

headers = {
    "ngrok-skip-browser-warning": "true",
    "Content-Type": "text/plain"
}

r = requests.post(
    f"{PUSHGATEWAY_URL}/metrics/job/aiperf",
    data=metrics,
    headers=headers
)
print(r.status_code)
# Out:
# 200

# %%
import pandas as pd
import json

df = pd.read_csv("/content/BurstGPT_data/BurstGPT_without_fails_3.csv")
df = df.head(200)

# نرتب حسب الوقت
df = df.sort_values("Timestamp").reset_index(drop=True)

# نحسب الوقت النسبي بالميلي ثانية
first_ts = df["Timestamp"].iloc[0]

with open("burstgpt_trace_timed.jsonl", "w") as f:
    for _, row in df.iterrows():
        entry = {
            "text": "x " * int(row["Request tokens"]),
            "output_length": int(row["Response tokens"]),
            "timestamp": int((row["Timestamp"] - first_ts) * 1000)
        }
        f.write(json.dumps(entry) + "\n")

print(f"تم تحويل {len(df)} طلب مع التوقيت")
# Out:
# تم تحويل 200 طلب مع التوقيت

# %%
import subprocess

result = subprocess.run([
    "aiperf", "profile", "facebook/opt-125m",
    "--url", "http://localhost:8000",
    "--endpoint-type", "completions",
    "--streaming",
    "--custom-dataset-type", "single-turn",
    "--input-file", "burstgpt_trace_timed.jsonl",
    "--request-count", "100",
    "--concurrency", "5",
    "--gpu-telemetry", "pynvml",
    "--ui-type", "simple",
    "--output-artifact-dir", "artifacts"
], capture_output=True, text=True)

print(result.stdout)
print(result.stderr)
# Out:
# 16:46:08.334 INFO     Starting AIPerf System (cli_runner.py:75)
# 16:46:08.908 INFO     ✓ Tokenizer facebook/opt-125m detected (tokenizer_display.py:203)
# 16:46:08.908 INFO     1 tokenizer validated • 0.6s (tokenizer_display.py:212)
# 16:46:09.185 INFO     Server Metrics: Discovered 1 endpoints: ['http://localhost:8000/metrics'] (manager.py:70)
# 16:46:09.204 INFO     Registered Server Metrics Manager (id: 'server_metrics_manager') (system_controller.py:340)
# 16:46:09.222 INFO     GPU telemetry export enabled: artifacts/gpu_telemetry_export.jsonl (jsonl_writer.py:53)
# 16:46:09.227 INFO     Registered Worker Manager (id: 'worker_manager') (system_controller.py:340)
# 16:46:09.231 INFO     Record metrics export enabled: artifacts/profile_export.jsonl (record_export_results_processor.py:53)
# 16:46:09.324 INFO     Registered Gpu Telemetry Manager (id: 'gpu_telemetry_manager') (system_controller.py:340)
# ...

# %%
import requests

PUSHGATEWAY_URL = "https://unrevised-tate-facetiously.ngrok-free.dev"

metrics = """
# HELP ttft_ms Time to first token in milliseconds
# TYPE ttft_ms gauge
ttft_ms 66.67

# HELP itl_ms Inter token latency in milliseconds
# TYPE itl_ms gauge
itl_ms 5.62

# HELP request_latency_ms Request latency in milliseconds
# TYPE request_latency_ms gauge
request_latency_ms 150.73

# HELP throughput_tokens_per_sec Output token throughput
# TYPE throughput_tokens_per_sec gauge
throughput_tokens_per_sec 468.91
"""

headers = {
    "ngrok-skip-browser-warning": "true",
    "Content-Type": "text/plain"
}

r = requests.post(
    f"{PUSHGATEWAY_URL}/metrics/job/aiperf",
    data=metrics,
    headers=headers
)
print(r.status_code)
# Out:
# 200
